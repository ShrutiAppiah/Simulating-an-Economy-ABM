# %%
#!/usr/bin/env python

import random
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()

            # Tick = Time step. At every tick, agents have to perform an action.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-14e753745bc9> in <module>()
#       1 import random
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 from mesa import Agent, Model
#       5 from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents
#
# ImportError: No module named 'matplotlib'

# %%
#!/usr/bin/env python

import random
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()

            # Tick = Time step. At every tick, agents have to perform an action.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-0f773885ab9f> in <module>()
#       2
#       3 import random
# ----> 4 import matplotlib.pyplot as plt
#       5
#       6 from mesa import Agent, Model
#
# ImportError: No module named 'matplotlib'

# %%
import sys
sys.path.append('my/path/to/module/folder')

import random
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-8d8bd49e15a3> in <module>()
#       3
#       4 import random
# ----> 5 import matplotlib.pyplot as plt
#       6
#       7 from mesa import Agent, Model
#
# ImportError: No module named 'matplotlib'

# %%
sys.version
# Out:
# '3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25) \n[GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]'

# %%
sys.version
# Out:
# '3.5.2 (v3.5.2:4def2a2901a5, Jun 26 2016, 10:47:25) \n[GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]'

# %%
import matplotlib.pyplot as plt

# %%
import random
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-134b5cd1e5ec> in <module>()
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 from mesa import Agent, Model
#       5 from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents
#       6
#
# ImportError: No module named 'mesa'

# %%
# %matplotlib inline

import random
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()

# %%
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.figure()
                plt.show()

# %%
plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.figure()
                plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.figure()
                plt.hist(all_wealth, bins=range(max(all_wealth)+1))

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.figure()
                plt.hist(all_wealth, bins=range(max(all_wealth)+1))

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.figure()
                plt.hist(all_wealth, bins=range(max(all_wealth)+1))

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

                plt.figure()
                plt.hist(all_wealth, bins=range(max(all_wealth)+1))
                plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

            plt.figure()
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

            plt.figure()
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()

# %%
X = randn(100000)
Y = randn(100000)
plot_correlated_data(X, Y)
print(np.cov(X, Y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-9f7b43ced087> in <module>()
# ----> 1 X = randn(100000)
#       2 Y = randn(100000)
#       3 plot_correlated_data(X, Y)
#       4 print(np.cov(X, Y))
#
# NameError: name 'randn' is not defined

# %%
from code.gaussian_internal import plot_correlated_data
import matplotlib.pyplot as plt

height = [60, 62, 63, 65, 65.1, 68, 69, 70, 72, 74]
weight = [95, 120, 127, 119, 151, 143, 173, 171, 180, 210]
plot_correlated_data(height, weight, 'Height (in)', 'Weight (lbs)', False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-25-237bcc6d0a3e> in <module>()
# ----> 1 from code.gaussian_internal import plot_correlated_data
#       2 import matplotlib.pyplot as plt
#       3
#       4 height = [60, 62, 63, 65, 65.1, 68, 69, 70, 72, 74]
#       5 weight = [95, 120, 127, 119, 151, 143, 173, 171, 180, 210]
#
# ImportError: No module named 'code.gaussian_internal'; 'code' is not a package

# %%
import matplotlib.pyplot as plt
from numpy.random import randn

X = randn(100000)
Y = randn(100000)
plot_correlated_data(X, Y)
print(np.cov(X, Y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-49ace61b7298> in <module>()
#       4 X = randn(100000)
#       5 Y = randn(100000)
# ----> 6 plot_correlated_data(X, Y)
#       7 print(np.cov(X, Y))
#
# NameError: name 'plot_correlated_data' is not defined

# %%
from code.gaussian_internal import plot_correlated_data

import matplotlib.pyplot as plt
from numpy.random import randn

X = randn(100000)
Y = randn(100000)
plot_correlated_data(X, Y)
print(np.cov(X, Y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-49ace61b7298> in <module>()
#       4 X = randn(100000)
#       5 Y = randn(100000)
# ----> 6 plot_correlated_data(X, Y)
#       7 print(np.cov(X, Y))
#
# NameError: name 'plot_correlated_data' is not defined

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)

            plt.figure()
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import matplotlib.pyplot as plt
import numpy as np

t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2*np.pi*t)
plt.plot(t, s)

plt.xlabel('time (s)')
plt.ylabel('voltage (mV)')
plt.title('About as simple as it gets, folks')
plt.grid(True)
plt.savefig("test.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print("All wealth", all_wealth);

            plt.figure()
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print("All wealth", all_wealth);

            plt.figure()
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print("All wealth", all_wealth);

            plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print("fndskjgd");
            print("All wealth", all_wealth);
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print("fndskjgd");
            print("All wealth", all_wealth);
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print('fndskjgd');
            print("All wealth", all_wealth);
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
print 'hello world'
# Out:
#   File "<ipython-input-2-d05d0c8adf1f>", line 1
#     print 'hello world'
#                       ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
import sys
#reload(sys)
#sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print('fndskjgd');
            print("All wealth", all_wealth);
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import sys
reload(sys)
sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
            print('fndskjgd')
            print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import sys
reload(sys)
sys.setdefaultencoding("utf-8")

import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
                    print('fndskjgd')
                    print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5fc93e401770> in <module>()
#       1 import sys
# ----> 2 reload(sys)
#       3 sys.setdefaultencoding("utf-8")
#       4
#       5 import random
#
# NameError: name 'reload' is not defined

# %%
print 'hhel'
# Out:
#   File "<ipython-input-6-c106e9eee3ee>", line 1
#     print 'hhel'
#                ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
print ('ehhre')
# Out:
# ehhre

# %%
print(all_wealth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-fcea8ab87a1f> in <module>()
# ----> 1 print(all_wealth)
#
# NameError: name 'all_wealth' is not defined

# %%
print("All wealth", all_wealth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-a4a8bf807877> in <module>()
# ----> 1 print("All wealth", all_wealth)
#
# NameError: name 'all_wealth' is not defined

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            
            empty_model = WealthModel(10)
            empty_model.step()

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
                    print('fndskjgd')
                    print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
# %matplotlib

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass
            print('1')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            print('4')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            agent_wealth = [a.wealth for a in model.schedule.agents]
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()
                    print('6')

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
                    print('fndskjgd')
                    print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass
            print('1')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
        def step(self):
            if self.wealth == 0:
                return
            other_agent = random.choice(self.model.schedule.agents)
            # Transaction - self's wealth transfers to other agent's wealth
            other_agent.wealth += 1
            self.wealth -= 1
            print('4')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            agent_wealth = [a.wealth for a in model.schedule.agents]
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()
                    print('6')

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
                    print('fndskjgd')
                    print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()
# Out:
# Using matplotlib backend: nbAgg

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
    def step(self):
        if self.wealth == 0:
            return
        other_agent = random.choice(self.model.schedule.agents)
        # Transaction - self's wealth transfers to other agent's wealth
        other_agent.wealth += 1
        self.wealth -= 1
        print('4')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
            agent_wealth = [a.wealth for a in model.schedule.agents]
            all_wealth = []
            for j in range(100):
                # Run the model
                model = WealthModel(10)
                for i in range(10):
                    model.step()
                    print('6')

                # Store the results
                for agent in model.schedule.agents:
                    all_wealth.append(agent.wealth)
                    
                    print('fndskjgd')
                    print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()

# %%
print ('fsf')
# Out:
# fsf

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass
            print('1')

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
        def step(self):
            # The agent's step will go here.
            pass
            print('1');

# %%
print(all_wealth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-fcea8ab87a1f> in <module>()
# ----> 1 print(all_wealth)
#
# NameError: name 'all_wealth' is not defined

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
    def step(self):
        if self.wealth == 0:
            return
        other_agent = random.choice(self.model.schedule.agents)
        # Transaction - self's wealth transfers to other agent's wealth
        other_agent.wealth += 1
        self.wealth -= 1
        print('4')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
        # agent_wealth = [a.wealth for a in model.schedule.agents]
        # all_wealth = []
        
        for j in range(100):
            # Run the model
            model = WealthModel(10)
            for i in range(10):
                model.step()
                print('6')

            # Store the results
            for agent in model.schedule.agents:
                all_wealth.append(agent.wealth)
                    
                print('fndskjgd')
                print("All wealth", all_wealth)
            
            #plt.figure()
        plt.plot(all_wealth, bins=range(max(all_wealth)+1))
        plt.hist(all_wealth, bins=range(max(all_wealth)+1))
        plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
    def step(self):
        if self.wealth == 0:
            return
        other_agent = random.choice(self.model.schedule.agents)
        # Transaction - self's wealth transfers to other agent's wealth
        other_agent.wealth += 1
        self.wealth -= 1
        print('4')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
        # agent_wealth = [a.wealth for a in model.schedule.agents]

        
        all_wealth = []
        for j in range(100):
            # Run the model
            model = WealthModel(10)
            for i in range(10):
                model.step()
                print('6')

            # Store the results
            for agent in model.schedule.agents:
                all_wealth.append(agent.wealth)
                    
                print('fndskjgd')
                print("All wealth", all_wealth)
            
            #plt.figure()
        plt.plot(all_wealth, bins=range(max(all_wealth)+1))
        plt.hist(all_wealth, bins=range(max(all_wealth)+1))
        plt.show()

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

from mesa import Agent, Model
from mesa.time import RandomActivation #RandomActivation is a simple scheduling style for activating agents


class WealthAgent(Agent):
    """An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        
        # Each agent begins with an allocated wealth
        self.wealth = 1
        
    def step(self):
        if self.wealth == 0:
            return
        other_agent = random.choice(self.model.schedule.agents)
        # Transaction - self's wealth transfers to other agent's wealth
        other_agent.wealth += 1
        self.wealth -= 1
        print('4')

class WealthModel(Model):
    """A model with some number of agents."""
    def __init__(self, N):
        
        # N number of agents in the organization
        self.num_agents = N
        self.schedule = RandomActivation(self)
        print('2')
        
        # Create agents
        for i in range(self.num_agents):
            a = WealthAgent(i, self)
            self.schedule.add(a) #Adds agents to the schedule
            #print("My Unique ID is:", unique_id)
            print('3')
            
            empty_model = WealthModel(10)
            empty_model.step()
            print('5')

           # model = WealthModel(10)
           # for i in range(10):
           #    model.step() 
    
        # agent_wealth = [a.wealth for a in model.schedule.agents]

        
        all_wealth = []
        for j in range(100):
            # Run the model
            model = WealthModel(10)
            for i in range(10):
                model.step()
                print('6')

            # Store the results
            for agent in model.schedule.agents:
                all_wealth.append(agent.wealth)
                    
                print('fndskjgd')
                print("All wealth", all_wealth)
            
            #plt.figure()
            plt.plot(all_wealth, bins=range(max(all_wealth)+1))
            plt.hist(all_wealth, bins=range(max(all_wealth)+1))
            plt.show()

# %%
import random

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()

# %%
import random

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
            
    plot(self.wealth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-6f90edaf4139> in <module>()
#      45
#      46
# ---> 47 class MoneyAgent(Agent):
#      48     """ An agent with fixed initial wealth."""
#      49     def __init__(self, unique_id, model):
#
# <ipython-input-24-6f90edaf4139> in MoneyAgent()
#      70             self.give_money()
#      71
# ---> 72     plot(self.wealth)
#
# NameError: name 'plot' is not defined

# %%
import random

import numpy as np
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
    
    plt.plot(self.wealth)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-c5dd90ca186c> in <module>()
#      48
#      49
# ---> 50 class MoneyAgent(Agent):
#      51     """ An agent with fixed initial wealth."""
#      52     def __init__(self, unique_id, model):
#
# <ipython-input-25-c5dd90ca186c> in MoneyAgent()
#      73             self.give_money()
#      74
# ---> 75     plt.plot(self.wealth)
#
# NameError: name 'self' is not defined

# %%
import random

import numpy as np
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
    
        plt.plot(self.wealth)

# %%
plt.show()

# %%
import random

import numpy as np
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
    
    plt.plot(self.wealth)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-2768754442cd> in <module>()
#      48
#      49
# ---> 50 class MoneyAgent(Agent):
#      51     """ An agent with fixed initial wealth."""
#      52     def __init__(self, unique_id, model):
#
# <ipython-input-28-2768754442cd> in MoneyAgent()
#      73             self.give_money()
#      74
# ---> 75     plt.plot(self.wealth)
#      76     plt.show()
#
# NameError: name 'self' is not defined

# %%
import random

import numpy as np
import matplotlib.pyplot as plt

from mesa import Agent, Model
from mesa.time import RandomActivation
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector


def compute_gini(model):
    agent_wealths = [agent.wealth for agent in model.schedule.agents]
    x = sorted(agent_wealths)
    N = model.num_agents
    B = sum(xi * (N - i) for i, xi in enumerate(x)) / (N * sum(x))
    return (1 + (1 / N) - 2 * B)


class MoneyModel(Model):
    """A model with some number of agents."""

    def __init__(self, N, width, height):
        self.num_agents = N
        self.running = True
        self.grid = MultiGrid(height, width, True)
        self.schedule = RandomActivation(self)
        self.datacollector = DataCollector(
            model_reporters={"Gini": compute_gini},
            agent_reporters={"Wealth": lambda a: a.wealth}
        )
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.datacollector.collect(self)
        self.schedule.step()

    def run_model(self, n):
        for i in range(n):
            self.step()


class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos, moore=True, include_center=False
        )
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
    
        plt.plot(self.wealth)
        plt.show()

# %%
class MoneyModel(Model):
    """A model with some number of agents."""
    def __init__(self, N, width, height):
        self.num_agents = N
        self.grid = MultiGrid(width, height, True)
        self.schedule = RandomActivation(self)
        # Create agents
        for i in range(self.num_agents):
            a = MoneyAgent(i, self)
            self.schedule.add(a)
            # Add the agent to a random grid cell
            x = random.randrange(self.grid.width)
            y = random.randrange(self.grid.height)
            self.grid.place_agent(a, (x, y))

    def step(self):
        self.schedule.step()

class MoneyAgent(Agent):
    """ An agent with fixed initial wealth."""
    def __init__(self, unique_id, model):
        super().__init__(unique_id, model)
        self.wealth = 1

    def move(self):
        possible_steps = self.model.grid.get_neighborhood(
            self.pos,
            moore=True,
            include_center=False)
        new_position = random.choice(possible_steps)
        self.model.grid.move_agent(self, new_position)

    def give_money(self):
        cellmates = self.model.grid.get_cell_list_contents([self.pos])
        if len(cellmates) > 1:
            other = random.choice(cellmates)
            other.wealth += 1
            self.wealth -= 1

    def step(self):
        self.move()
        if self.wealth > 0:
            self.give_money()
